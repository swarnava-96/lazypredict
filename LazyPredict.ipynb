# %% [markdown]
# <a href="https://colab.research.google.com/github/swarnava-96/lazypredict/blob/main/LazyPredict.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install lazypredict

# %%
import lazypredict

# %% [markdown]
# ## lazypredict Classifier

# %%
from lazypredict.Supervised import LazyClassifier
from sklearn.datasets import load_breast_cancer
from sklearn.model_selection import train_test_split

data=load_breast_cancer()
X=data.data
y=data.target

X_train,X_test,y_train,y_test=train_test_split(X,y,test_size=0.3,random_state=123)

clf=LazyClassifier(verbose=0,ignore_warnings=True,custom_metric=None)
models,predictions=clf.fit(X_train,X_test,y_train,y_test)

print(models)
# Out:
# 100%|██████████| 29/29 [00:01<00:00, 17.13it/s]
#                                Accuracy  ...  Time Taken
# Model                                    ...
# LogisticRegression                 0.99  ...        0.05
# SGDClassifier                      0.99  ...        0.03
# LinearSVC                          0.99  ...        0.06
# Perceptron                         0.99  ...        0.03
# SVC                                0.98  ...        0.03
# RandomForestClassifier             0.98  ...        0.24
# ExtraTreesClassifier               0.98  ...        0.16
# RidgeClassifier                    0.98  ...        0.02
# QuadraticDiscriminantAnalysis      0.98  ...        0.02
# AdaBoostClassifier                 0.98  ...        0.17
# KNeighborsClassifier               0.98  ...        0.02
# LinearDiscriminantAnalysis         0.98  ...        0.05
# CalibratedClassifierCV             0.98  ...        0.05
# LGBMClassifier                     0.97  ...        0.16
# ...

# %%
models
# Out:
#                                Accuracy  ...  Time Taken
# Model                                    ...
# LogisticRegression                 0.99  ...        0.05
# SGDClassifier                      0.99  ...        0.03
# LinearSVC                          0.99  ...        0.06
# Perceptron                         0.99  ...        0.03
# SVC                                0.98  ...        0.03
# RandomForestClassifier             0.98  ...        0.24
# ExtraTreesClassifier               0.98  ...        0.16
# RidgeClassifier                    0.98  ...        0.02
# QuadraticDiscriminantAnalysis      0.98  ...        0.02
# AdaBoostClassifier                 0.98  ...        0.17
# KNeighborsClassifier               0.98  ...        0.02
# LinearDiscriminantAnalysis         0.98  ...        0.05
# CalibratedClassifierCV             0.98  ...        0.05
# LGBMClassifier                     0.97  ...        0.16
# XGBClassifier                      0.97  ...        0.24
# ...

# %% [markdown]
# ## lazypredict Regressor

# %%
from lazypredict.Supervised import LazyRegressor
from sklearn import datasets
from sklearn.utils import shuffle
import numpy as np

boston = datasets.load_boston()
X, y = shuffle(boston.data, boston.target, random_state=13)


offset = int(X.shape[0] * 0.9)

X_train, y_train = X[:offset], y[:offset]
X_test, y_test = X[offset:], y[offset:]

reg = LazyRegressor(verbose=0, ignore_warnings=False, custom_metric=None)
models, predictions = reg.fit(X_train, X_test, y_train, y_test)

print(models)
# Out:
# 100%|██████████| 42/42 [00:03<00:00, 12.67it/s]
#                                Adjusted R-Squared  R-Squared  RMSE  Time Taken
# Model
# SVR                                          0.83       0.88  2.62        0.03
# BaggingRegressor                             0.83       0.88  2.63        0.06
# NuSVR                                        0.82       0.86  2.76        0.04
# RandomForestRegressor                        0.81       0.86  2.79        0.39
# XGBRegressor                                 0.81       0.86  2.79        0.10
# GradientBoostingRegressor                    0.81       0.86  2.84        0.17
# ExtraTreesRegressor                          0.79       0.84  2.98        0.23
# HistGradientBoostingRegressor                0.77       0.83  3.06        0.40
# AdaBoostRegressor                            0.77       0.83  3.06        0.14
# PoissonRegressor                             0.77       0.83  3.11        0.02
# ...

# %%
models
# Out:
#                                Adjusted R-Squared  R-Squared  RMSE  Time Taken
# Model
# SVR                                          0.83       0.88  2.62        0.03
# BaggingRegressor                             0.83       0.88  2.63        0.06
# NuSVR                                        0.82       0.86  2.76        0.04
# RandomForestRegressor                        0.81       0.86  2.79        0.39
# XGBRegressor                                 0.81       0.86  2.79        0.10
# GradientBoostingRegressor                    0.81       0.86  2.84        0.17
# ExtraTreesRegressor                          0.79       0.84  2.98        0.23
# HistGradientBoostingRegressor                0.77       0.83  3.06        0.40
# AdaBoostRegressor                            0.77       0.83  3.06        0.14
# PoissonRegressor                             0.77       0.83  3.11        0.02
# LGBMRegressor                                0.77       0.83  3.11        0.08
# ...

# %% [markdown]
# ## lazypredict on Titanic dataset

# %%
import seaborn as sns

# %%
df=sns.load_dataset('titanic')

# %%
df.head()
# Out:
#    survived  pclass     sex   age  ...  deck  embark_town  alive  alone
# 0         0       3    male 22.00  ...   NaN  Southampton     no  False
# 1         1       1  female 38.00  ...     C    Cherbourg    yes  False
# 2         1       3  female 26.00  ...   NaN  Southampton    yes   True
# 3         1       1  female 35.00  ...     C  Southampton    yes  False
# 4         0       3    male 35.00  ...   NaN  Southampton     no   True
#
# [5 rows x 15 columns]

# %%
X=df.drop('survived',axis=1)
y=df.iloc[:,0]

# %%
X.head()
# Out:
#    pclass     sex   age  sibsp  ...  deck  embark_town alive  alone
# 0       3    male 22.00      1  ...   NaN  Southampton    no  False
# 1       1  female 38.00      1  ...     C    Cherbourg   yes  False
# 2       3  female 26.00      0  ...   NaN  Southampton   yes   True
# 3       1  female 35.00      1  ...     C  Southampton   yes  False
# 4       3    male 35.00      0  ...   NaN  Southampton    no   True
#
# [5 rows x 14 columns]

# %%
y
# Out:
# 0      0
# 1      1
# 2      1
# 3      1
# 4      0
#       ..
# 886    0
# 887    1
# 888    0
# 889    1
# 890    0
# Name: survived, Length: 891, dtype: int64

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X, y,test_size=.25,random_state =123)

# %%
clf = LazyClassifier(verbose=0, ignore_warnings=False, custom_metric=None)
models,predictions = clf.fit(X_train, X_test, y_train, y_test)
# Out:
#  21%|██        | 6/29 [00:00<00:01, 21.48it/s]
# CategoricalNB model failed to execute
# Negative values in data passed to CategoricalNB (input X)
# 100%|██████████| 29/29 [00:01<00:00, 17.03it/s]
# StackingClassifier model failed to execute
# __init__() missing 1 required positional argument: 'estimators'

# %%
print(models)
# Out:
#                                Accuracy  ...  Time Taken
# Model                                    ...
# AdaBoostClassifier                 1.00  ...        0.03
# BaggingClassifier                  1.00  ...        0.05
# XGBClassifier                      1.00  ...        0.08
# SVC                                1.00  ...        0.07
# SGDClassifier                      1.00  ...        0.05
# RidgeClassifierCV                  1.00  ...        0.05
# RidgeClassifier                    1.00  ...        0.04
# RandomForestClassifier             1.00  ...        0.23
# Perceptron                         1.00  ...        0.03
# PassiveAggressiveClassifier        1.00  ...        0.03
# LogisticRegression                 1.00  ...        0.05
# LinearSVC                          1.00  ...        0.08
# GaussianNB                         1.00  ...        0.03
# ExtraTreesClassifier               1.00  ...        0.16
# ExtraTreeClassifier                1.00  ...        0.03
# ...

# %%
models
# Out:
#                                Accuracy  ...  Time Taken
# Model                                    ...
# AdaBoostClassifier                 1.00  ...        0.03
# BaggingClassifier                  1.00  ...        0.05
# XGBClassifier                      1.00  ...        0.08
# SVC                                1.00  ...        0.07
# SGDClassifier                      1.00  ...        0.05
# RidgeClassifierCV                  1.00  ...        0.05
# RidgeClassifier                    1.00  ...        0.04
# RandomForestClassifier             1.00  ...        0.23
# Perceptron                         1.00  ...        0.03
# PassiveAggressiveClassifier        1.00  ...        0.03
# LogisticRegression                 1.00  ...        0.05
# LinearSVC                          1.00  ...        0.08
# GaussianNB                         1.00  ...        0.03
# ExtraTreesClassifier               1.00  ...        0.16
# ExtraTreeClassifier                1.00  ...        0.03
# ...
